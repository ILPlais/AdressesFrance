# %% [markdown]
# <a href="https://colab.research.google.com/github/ILPlais/AdressesFrance/blob/main/VideosConvertSubtitle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install packages

# %%
# !pip install --requirement=requirements.txt

# %% [markdown]
# # Download the videos

# %%
# !python3 ./DownloadWMV.py

# %% [markdown]
# # Convert the videos to WebM

# %%
# !python3 ./ConvertWMV2WebM.py --send-after

# %% [markdown]
# # Use Whisler to make the subtitles

# %%
# !python3 ./TranscriptVideos.py --send-after --language fr
